# %% [markdown]
# This version change the inage data itself.

# %%
import numpy as np
import random

from keras.layers import Input,merge
from keras.layers.core import Reshape, Dense, Dropout, Activation, Flatten
from keras.layers.advanced_activations import LeakyReLU
from keras.layers.convolutional import Cropping2D, Convolution2D, Deconvolution2D
from keras.layers.normalization import BatchNormalization
from keras.optimizers import Adam, SGD
import keras
from keras.models import Model, load_model

from tqdm import tqdm

# %%
from sklearn.externals import joblib
import numpy as np

def load_train(filename, dim_ordering = 'th', debug = True, bgr_to_rgb = False) :
    # Expects files to be loaded and pickled as RGB image 
    X = joblib.load(filename)['X']

    # Scale color range from (0, 1) to (-1, 1)
    X = X * 2 - 1
    assert np.min(X) >= -1.0 and np.max(X) <= 1.0
    if debug :
        print("Color range: ", np.min(X), np.max(X))
    
    if bgr_to_rgb :
        X = X[:, :, :, [2, 1, 0]]
    
    assert X.shape[-1] == 3
    if dim_ordering == 'th' :
        # Change dim_ordering from TF (count_images, height, width, 3) to theano (count_images, 3, height, width)
        X = np.swapaxes(X, 2, 3)
        X = np.swapaxes(X, 1, 2)
    elif dim_ordering == 'tf' :
        pass
    else :
        raise ValueError('Dim ordering %s is not supported' % dim_ordering)
    
    if debug :
        print('Shape:', X.shape)
    
    return X

# %%
# %%time
X = load_train('video.frame.96.dump')
# Out:
# Color range:  -1.0 1.0
# Shape: (12300, 3, 96, 96)
# CPU times: user 2.16 s, sys: 4.51 s, total: 6.67 s
# Wall time: 47.5 s

# %%
def generator_block(input_node, input_shape, leaku_relu_alpha) :    
    channels, height, width = input_shape
    output_shape = (None, channels // 2, height * 2 + 2, width * 2 + 2)  
    
    block = Deconvolution2D(
        output_shape[1], 
        4, 4, 
        output_shape = output_shape, 
        border_mode='valid', 
        init='glorot_uniform', 
        subsample = (2, 2),
    )(input_node)
    block = Cropping2D(((1, 1), (1, 1)))(block)
    block = BatchNormalization(mode = 2)(block)
    block = LeakyReLU(leaku_relu_alpha)(block)

    return block


def build_generator(initial_size = (3, 3), channels_count = 32 * 32, leaky_relu_alpha = 0.2) :
    generator_input = Input(shape=[100])
    
    initial_height, initial_width = initial_size
    
    H = Dense(channels_count * initial_height * initial_width, init='glorot_normal')(generator_input)
    H = BatchNormalization(mode = 2)(H)
    H = LeakyReLU(0.2)(H)
    H = Reshape([channels_count, initial_height, initial_width] )(H) # nch

    # 4 layers result in x16 increased picture size, (3, 3) -> (48, 48)

    H = generator_block(H, (channels_count, initial_height, initial_width), leaky_relu_alpha)
    H = generator_block(H, (channels_count // 2 , initial_height * 2, initial_width * 2), leaky_relu_alpha)
    H = generator_block(H, (channels_count // 4 , initial_height * 4, initial_width * 4), leaky_relu_alpha)
    H = generator_block(H, (channels_count // 8 , initial_height * 8, initial_width * 8), leaky_relu_alpha)
    H = generator_block(H, (channels_count // 16 , initial_height * 16, initial_width * 16), leaky_relu_alpha)

    H = Convolution2D(channels_count // 32, 3, 3, border_mode='same', init='glorot_uniform')(H)
    H = BatchNormalization(mode = 2)(H)
    H = LeakyReLU(leaky_relu_alpha)(H)

    H = Convolution2D(3, 1, 1, border_mode='same', init='glorot_uniform')(H)
    generator_output = Activation('tanh')(H)

    generator = Model(generator_input, generator_output)
    generator_output_shape = (3, initial_height * 32, initial_width * 32)

    return generator, generator_input, generator_output_shape


def build_discriminator(input_shape, discriminator_base_channels = 64, leaky_relu_alpha = 0.2, dropout_rate = 0.25) :
    discriminator_input = Input(shape = input_shape)
    H = Convolution2D(discriminator_base_channels * 3, 5, 5, subsample=(2, 2), border_mode = 'same', activation='relu')(discriminator_input)
    H = LeakyReLU(leaky_relu_alpha)(H)
    H = Dropout(dropout_rate)(H)
    
    H = Convolution2D(discriminator_base_channels * 4, 5, 5, subsample=(2, 2), border_mode = 'same', activation='relu')(H)
    H = LeakyReLU(leaky_relu_alpha)(H)
    H = Dropout(dropout_rate)(H)
    
    H = Convolution2D(discriminator_base_channels * 4, 5, 5, subsample=(2, 2), border_mode = 'same', activation='relu')(H)
    H = LeakyReLU(leaky_relu_alpha)(H)
    H = Dropout(dropout_rate)(H)
    
    H = Convolution2D(discriminator_base_channels * 6, 3, 3, subsample=(2, 2), border_mode = 'same', activation='relu')(H)
    H = LeakyReLU(leaky_relu_alpha)(H)
    H = Dropout(dropout_rate)(H)
    
    H = Convolution2D(discriminator_base_channels * 3, 1, 1, border_mode = 'same', activation='relu')(H)
    H = LeakyReLU(leaky_relu_alpha)(H)
    H = Dropout(dropout_rate)(H)
    
    H = Flatten()(H)
    
    H = Dense(discriminator_base_channels * 2)(H)
    H = LeakyReLU(0.2)(H)
    discriminator_output = Dense(2, activation='softmax')(H)
    
    discriminator = Model(discriminator_input, discriminator_output)
    return discriminator, discriminator_output
    
    
def make_trainable(model, mode):
    model.trainable = mode
    for layer in model.layers:
        layer.trainable = mode
    
    
def build_models(
    debug = True, 
    generator_optimizer = Adam(lr = 5e-4), 
    discriminator_optimizer = SGD(lr=5e-2),
    discriminator_dropout_rate = 0.25,
    generator_initial_size = (3, 3),
) :
    generator, generator_input, generator_output_shape = build_generator(generator_initial_size) 
    generator.compile(loss='binary_crossentropy', optimizer = generator_optimizer, metrics = ['accuracy'])

    if debug :
        generator.summary()
    
    input_shape = generator_output_shape
    discriminator, discriminator_output = build_discriminator(input_shape, dropout_rate = discriminator_dropout_rate)
    discriminator.compile(loss='categorical_crossentropy', optimizer = discriminator_optimizer, metrics = ['accuracy'])
    if debug :
        discriminator.summary()
        
    # Freeze weights in the discriminator for stacked training
    make_trainable(discriminator, False)
    
    gan_input = Input(shape=[100])
    H = generator(gan_input)
    gan_output = discriminator(H)
    gan = Model(gan_input, gan_output)
    gan.compile(loss='categorical_crossentropy', optimizer=generator_optimizer, metrics = ['accuracy'])
    if debug :
        gan.summary()
        
    return generator, discriminator, gan, generator_optimizer, discriminator_optimizer

# %%
generator, discriminator, gan, generator_optimizer, discriminator_optimizer = build_models()
# Out:
# ____________________________________________________________________________________________________
# Layer (type)                     Output Shape          Param #     Connected to
# ====================================================================================================
# input_4 (InputLayer)             (None, 100)           0
# ____________________________________________________________________________________________________
# dense_4 (Dense)                  (None, 9216)          930816      input_4[0][0]
# ____________________________________________________________________________________________________
# batchnormalization_8 (BatchNorma (None, 9216)          36864       dense_4[0][0]
# ____________________________________________________________________________________________________
# leakyrelu_14 (LeakyReLU)         (None, 9216)          0           batchnormalization_8[0][0]
# ____________________________________________________________________________________________________
# reshape_2 (Reshape)              (None, 1024, 3, 3)    0           leakyrelu_14[0][0]
# ____________________________________________________________________________________________________
# deconvolution2d_6 (Deconvolution (None, 512, 8, 8)     8389120     reshape_2[0][0]
# ____________________________________________________________________________________________________
# cropping2d_6 (Cropping2D)        (None, 512, 6, 6)     0           deconvolution2d_6[0][0]
# ____________________________________________________________________________________________________
# batchnormalization_9 (BatchNorma (None, 512, 6, 6)     24          cropping2d_6[0][0]
# ____________________________________________________________________________________________________
# leakyrelu_15 (LeakyReLU)         (None, 512, 6, 6)     0           batchnormalization_9[0][0]
# ____________________________________________________________________________________________________
# deconvolution2d_7 (Deconvolution (None, 256, 14, 14)   2097408     leakyrelu_15[0][0]
# ____________________________________________________________________________________________________
# cropping2d_7 (Cropping2D)        (None, 256, 12, 12)   0           deconvolution2d_7[0][0]
# ____________________________________________________________________________________________________
# batchnormalization_10 (BatchNorm (None, 256, 12, 12)   48          cropping2d_7[0][0]
# ____________________________________________________________________________________________________
# leakyrelu_16 (LeakyReLU)         (None, 256, 12, 12)   0           batchnormalization_10[0][0]
# ____________________________________________________________________________________________________
# deconvolution2d_8 (Deconvolution (None, 128, 26, 26)   524416      leakyrelu_16[0][0]
# ____________________________________________________________________________________________________
# cropping2d_8 (Cropping2D)        (None, 128, 24, 24)   0           deconvolution2d_8[0][0]
# ____________________________________________________________________________________________________
# batchnormalization_11 (BatchNorm (None, 128, 24, 24)   96          cropping2d_8[0][0]
# ____________________________________________________________________________________________________
# leakyrelu_17 (LeakyReLU)         (None, 128, 24, 24)   0           batchnormalization_11[0][0]
# ____________________________________________________________________________________________________
# deconvolution2d_9 (Deconvolution (None, 64, 50, 50)    131136      leakyrelu_17[0][0]
# ____________________________________________________________________________________________________
# cropping2d_9 (Cropping2D)        (None, 64, 48, 48)    0           deconvolution2d_9[0][0]
# ____________________________________________________________________________________________________
# batchnormalization_12 (BatchNorm (None, 64, 48, 48)    192         cropping2d_9[0][0]
# ____________________________________________________________________________________________________
# leakyrelu_18 (LeakyReLU)         (None, 64, 48, 48)    0           batchnormalization_12[0][0]
# ____________________________________________________________________________________________________
# deconvolution2d_10 (Deconvolutio (None, 32, 98, 98)    32800       leakyrelu_18[0][0]
# ____________________________________________________________________________________________________
# cropping2d_10 (Cropping2D)       (None, 32, 96, 96)    0           deconvolution2d_10[0][0]
# ____________________________________________________________________________________________________
# batchnormalization_13 (BatchNorm (None, 32, 96, 96)    384         cropping2d_10[0][0]
# ____________________________________________________________________________________________________
# leakyrelu_19 (LeakyReLU)         (None, 32, 96, 96)    0           batchnormalization_13[0][0]
# ____________________________________________________________________________________________________
# convolution2d_8 (Convolution2D)  (None, 32, 96, 96)    9248        leakyrelu_19[0][0]
# ____________________________________________________________________________________________________
# batchnormalization_14 (BatchNorm (None, 32, 96, 96)    384         convolution2d_8[0][0]
# ____________________________________________________________________________________________________
# leakyrelu_20 (LeakyReLU)         (None, 32, 96, 96)    0           batchnormalization_14[0][0]
# ____________________________________________________________________________________________________
# convolution2d_9 (Convolution2D)  (None, 3, 96, 96)     99          leakyrelu_20[0][0]
# ____________________________________________________________________________________________________
# activation_2 (Activation)        (None, 3, 96, 96)     0           convolution2d_9[0][0]
# ====================================================================================================
# Total params: 12,153,035
# Trainable params: 12,134,039
# Non-trainable params: 18,996
# ____________________________________________________________________________________________________
# ____________________________________________________________________________________________________
# Layer (type)                     Output Shape          Param #     Connected to
# ====================================================================================================
# input_5 (InputLayer)             (None, 3, 96, 96)     0
# ____________________________________________________________________________________________________
# convolution2d_10 (Convolution2D) (None, 192, 48, 48)   14592       input_5[0][0]
# ____________________________________________________________________________________________________
# leakyrelu_21 (LeakyReLU)         (None, 192, 48, 48)   0           convolution2d_10[0][0]
# ____________________________________________________________________________________________________
# dropout_6 (Dropout)              (None, 192, 48, 48)   0           leakyrelu_21[0][0]
# ____________________________________________________________________________________________________
# convolution2d_11 (Convolution2D) (None, 256, 24, 24)   1229056     dropout_6[0][0]
# ____________________________________________________________________________________________________
# leakyrelu_22 (LeakyReLU)         (None, 256, 24, 24)   0           convolution2d_11[0][0]
# ____________________________________________________________________________________________________
# dropout_7 (Dropout)              (None, 256, 24, 24)   0           leakyrelu_22[0][0]
# ____________________________________________________________________________________________________
# convolution2d_12 (Convolution2D) (None, 256, 12, 12)   1638656     dropout_7[0][0]
# ____________________________________________________________________________________________________
# leakyrelu_23 (LeakyReLU)         (None, 256, 12, 12)   0           convolution2d_12[0][0]
# ____________________________________________________________________________________________________
# dropout_8 (Dropout)              (None, 256, 12, 12)   0           leakyrelu_23[0][0]
# ____________________________________________________________________________________________________
# convolution2d_13 (Convolution2D) (None, 384, 6, 6)     885120      dropout_8[0][0]
# ____________________________________________________________________________________________________
# leakyrelu_24 (LeakyReLU)         (None, 384, 6, 6)     0           convolution2d_13[0][0]
# ____________________________________________________________________________________________________
# dropout_9 (Dropout)              (None, 384, 6, 6)     0           leakyrelu_24[0][0]
# ____________________________________________________________________________________________________
# convolution2d_14 (Convolution2D) (None, 192, 6, 6)     73920       dropout_9[0][0]
# ____________________________________________________________________________________________________
# leakyrelu_25 (LeakyReLU)         (None, 192, 6, 6)     0           convolution2d_14[0][0]
# ____________________________________________________________________________________________________
# dropout_10 (Dropout)             (None, 192, 6, 6)     0           leakyrelu_25[0][0]
# ____________________________________________________________________________________________________
# flatten_2 (Flatten)              (None, 6912)          0           dropout_10[0][0]
# ____________________________________________________________________________________________________
# dense_5 (Dense)                  (None, 128)           884864      flatten_2[0][0]
# ____________________________________________________________________________________________________
# leakyrelu_26 (LeakyReLU)         (None, 128)           0           dense_5[0][0]
# ____________________________________________________________________________________________________
# dense_6 (Dense)                  (None, 2)             258         leakyrelu_26[0][0]
# ====================================================================================================
# Total params: 4,726,466
# Trainable params: 4,726,466
# Non-trainable params: 0
# ____________________________________________________________________________________________________
# ____________________________________________________________________________________________________
# Layer (type)                     Output Shape          Param #     Connected to
# ====================================================================================================
# input_6 (InputLayer)             (None, 100)           0
# ____________________________________________________________________________________________________
# model_4 (Model)                  (None, 3, 96, 96)     12153035    input_6[0][0]
# ____________________________________________________________________________________________________
# model_5 (Model)                  (None, 2)             4726466     model_4[1][0]
# ====================================================================================================
# Total params: 16,879,501
# Trainable params: 12,134,039
# Non-trainable params: 4,745,462
# ____________________________________________________________________________________________________

# %%
def noise_generator(batch, size = 100) :
    # Normal (0, 1) noise instead of uniform as in original DCGAN 
    return np.random.normal(0, 1, size=[batch,100])

# %%
# Pre-train the discriminator network ...
def pretrain_discriminator(discriminator, X, pretrain_size = 1000) :
    train_ids = random.sample(range(0, X.shape[0]), pretrain_size)
    X_pretrain = X[train_ids, :, :, :]

    noise = noise_generator(pretrain_size)
    generated_images = generator.predict(noise)
    X_pretrain = np.concatenate([X_pretrain, generated_images])

    y = np.zeros([pretrain_size * 2, 2])
    # Real images
    y[:pretrain_size, 1] = 1    
    # Generated
    y[pretrain_size:, 0] = 1

    make_trainable(discriminator, True)
    discriminator.fit(X_pretrain, y, nb_epoch=2, batch_size=64, verbose = 0)
    return discriminator.evaluate(X_pretrain, y, verbose = 0)

# %%
# %%time

pretrain_discriminator(discriminator, X)
# Out:
# CPU times: user 39.1 s, sys: 5.74 s, total: 44.8 s
# Wall time: 44.8 s
# [0.00035673492378555238, 1.0]

# %%
def history_replay(history, batch_size) :
    assert batch_size % len(history) == 0
    
    history_batch = []
    for history_images in history :
        images_count = batch_size // len(history)
        history_batch.append(
            history_images[
                np.random.randint(0, history_images.shape[0], size = images_count)
            ]
        )
    history_batch = np.concatenate(history_batch)
    return history_batch


def train_discriminator(discriminator, history, X, batch_size, losses) :
    make_trainable(discriminator, True)

    X_fake = history_replay(history, batch_size)
    y = np.zeros([batch_size, 2])
    
    # Soft-noisy labels
    y[:, 0] = np.random.uniform(0.7, 1.0, size=[batch_size])
    y[:, 1] = -y[:, 0] + 1.0
    
    loss_fake, accuracy_fake = discriminator.train_on_batch(X_fake, y)
    
    X_real = X[np.random.randint(0, X.shape[0],size = batch_size),:,:,:]    
    y = np.zeros([batch_size, 2])
    y[:, 1] = np.random.uniform(0.7, 1.2, size=[batch_size])
    y[:, 0] = -y[:, 1] + 1.0
    
    loss_real, accuracy_real  = discriminator.train_on_batch(X_real, y)
    for name, loss in [
        ('discriminator accuracy real', accuracy_real),
        ('discriminator accuracy fake', accuracy_fake),
        ('discriminator logloss real', loss_real),
        ('discriminator logloss fake', loss_fake),
    ] :
        losses[name].append(loss)

        
def train_generator(gan, generator, batch_size, losses) :
    g_loss = 0
    make_trainable(discriminator, False)
    noise = noise_generator(batch_size)
    y = np.zeros([batch_size,  2])
    y[:, 1] = 1

    loss, accuracy = gan.train_on_batch(noise, y)
    for name, loss in [
        ('generator accuracy', accuracy),
        ('generator logloss', loss),
    ] :
        losses[name].append(loss)

# !mkdir samples
# !mkdir samples/tiled-96
# !mkdir samples/tiled-96/shaking
        
rows, columns = 9, 9

def save_models(generator, discriminator, gan) :
    generator.save('generator.model')
    discriminator.save('discriminator.model')
    gan.save('gan.model')
    
def load_models():
    generator, discriminator, gan, generator_optimizer, discriminator_optimizer = build_models()
    
    _gan = load_model('gan.model')
    gan.set_weights(_gan.get_weights())
    generator.set_weights(_gan.layers[1].get_weights())
    discriminator.set_weights(_gan.layers[2].get_weights())
    return generator, discriminator, gan, generator_optimizer, discriminator_optimizer
    
def train_gan(discriminator, gan, generator, losses, epoch_count = 500000, plot_frequency = 50, render_frequency = 1000, batch_size = 32,
              history_length = 8, train_dis = True, train_gen = True, display_loss_length = None) :
    # History replay-like heuristic used to train discriminator 
    history = []
    for i in range(history_length - 1) : 
        noise = noise_generator(batch_size)
        generated_images = generator.predict(noise)    
        history.append(generated_images)
        
    for epoch in tqdm(range(epoch_count)) :
        noise_gen = np.random.uniform(0, 1, size=[batch_size,100])
        generated_images = generator.predict(noise_gen)
        history.append(generated_images)
        
        if train_dis:
            train_discriminator(discriminator, history, X, batch_size, losses)
        if train_gen:
            train_generator(gan, generator, batch_size, losses)

        history.pop(random.choice(range(history_length)))
        
        if epoch % plot_frequency == 0 :
            plot_loss(losses, display_loss_length = display_loss_length)
            plot_generator()
            
        if epoch % render_frequency == 0 :
            images = image_shaking(generator, images_count = rows, shakes_count = columns, noise = fixed_noise[:rows])
            save_tiled(
                images, 
                'samples/tiled-96/shaking/epoch-%d.png' % epoch, 
                rows, 
                columns,
                image_size = (96, 96)
            )
            save_models(generator, discriminator, gan)
# Out:
# mkdir: cannot create directory ‘samples’: File exists
# mkdir: cannot create directory ‘samples/tiled-96’: File exists
# mkdir: cannot create directory ‘samples/tiled-96/shaking’: File exists

# %%
#generator, discriminator, gan, generator_optimizer, discriminator_optimizer = load_models()
# Out:
# ____________________________________________________________________________________________________
# Layer (type)                     Output Shape          Param #     Connected to
# ====================================================================================================
# input_10 (InputLayer)            (None, 100)           0
# ____________________________________________________________________________________________________
# dense_10 (Dense)                 (None, 9216)          930816      input_10[0][0]
# ____________________________________________________________________________________________________
# batchnormalization_22 (BatchNorm (None, 9216)          36864       dense_10[0][0]
# ____________________________________________________________________________________________________
# leakyrelu_40 (LeakyReLU)         (None, 9216)          0           batchnormalization_22[0][0]
# ____________________________________________________________________________________________________
# reshape_4 (Reshape)              (None, 1024, 3, 3)    0           leakyrelu_40[0][0]
# ____________________________________________________________________________________________________
# deconvolution2d_16 (Deconvolutio (None, 512, 8, 8)     8389120     reshape_4[0][0]
# ____________________________________________________________________________________________________
# cropping2d_16 (Cropping2D)       (None, 512, 6, 6)     0           deconvolution2d_16[0][0]
# ____________________________________________________________________________________________________
# batchnormalization_23 (BatchNorm (None, 512, 6, 6)     24          cropping2d_16[0][0]
# ____________________________________________________________________________________________________
# leakyrelu_41 (LeakyReLU)         (None, 512, 6, 6)     0           batchnormalization_23[0][0]
# ____________________________________________________________________________________________________
# deconvolution2d_17 (Deconvolutio (None, 256, 14, 14)   2097408     leakyrelu_41[0][0]
# ____________________________________________________________________________________________________
# cropping2d_17 (Cropping2D)       (None, 256, 12, 12)   0           deconvolution2d_17[0][0]
# ____________________________________________________________________________________________________
# batchnormalization_24 (BatchNorm (None, 256, 12, 12)   48          cropping2d_17[0][0]
# ____________________________________________________________________________________________________
# leakyrelu_42 (LeakyReLU)         (None, 256, 12, 12)   0           batchnormalization_24[0][0]
# ____________________________________________________________________________________________________
# deconvolution2d_18 (Deconvolutio (None, 128, 26, 26)   524416      leakyrelu_42[0][0]
# ____________________________________________________________________________________________________
# cropping2d_18 (Cropping2D)       (None, 128, 24, 24)   0           deconvolution2d_18[0][0]
# ____________________________________________________________________________________________________
# batchnormalization_25 (BatchNorm (None, 128, 24, 24)   96          cropping2d_18[0][0]
# ____________________________________________________________________________________________________
# leakyrelu_43 (LeakyReLU)         (None, 128, 24, 24)   0           batchnormalization_25[0][0]
# ____________________________________________________________________________________________________
# deconvolution2d_19 (Deconvolutio (None, 64, 50, 50)    131136      leakyrelu_43[0][0]
# ____________________________________________________________________________________________________
# cropping2d_19 (Cropping2D)       (None, 64, 48, 48)    0           deconvolution2d_19[0][0]
# ____________________________________________________________________________________________________
# batchnormalization_26 (BatchNorm (None, 64, 48, 48)    192         cropping2d_19[0][0]
# ____________________________________________________________________________________________________
# leakyrelu_44 (LeakyReLU)         (None, 64, 48, 48)    0           batchnormalization_26[0][0]
# ____________________________________________________________________________________________________
# deconvolution2d_20 (Deconvolutio (None, 32, 98, 98)    32800       leakyrelu_44[0][0]
# ____________________________________________________________________________________________________
# cropping2d_20 (Cropping2D)       (None, 32, 96, 96)    0           deconvolution2d_20[0][0]
# ____________________________________________________________________________________________________
# batchnormalization_27 (BatchNorm (None, 32, 96, 96)    384         cropping2d_20[0][0]
# ____________________________________________________________________________________________________
# leakyrelu_45 (LeakyReLU)         (None, 32, 96, 96)    0           batchnormalization_27[0][0]
# ____________________________________________________________________________________________________
# convolution2d_22 (Convolution2D) (None, 32, 96, 96)    9248        leakyrelu_45[0][0]
# ____________________________________________________________________________________________________
# batchnormalization_28 (BatchNorm (None, 32, 96, 96)    384         convolution2d_22[0][0]
# ____________________________________________________________________________________________________
# leakyrelu_46 (LeakyReLU)         (None, 32, 96, 96)    0           batchnormalization_28[0][0]
# ____________________________________________________________________________________________________
# convolution2d_23 (Convolution2D) (None, 3, 96, 96)     99          leakyrelu_46[0][0]
# ____________________________________________________________________________________________________
# activation_4 (Activation)        (None, 3, 96, 96)     0           convolution2d_23[0][0]
# ====================================================================================================
# Total params: 12,153,035
# Trainable params: 12,134,039
# Non-trainable params: 18,996
# ____________________________________________________________________________________________________
# ____________________________________________________________________________________________________
# Layer (type)                     Output Shape          Param #     Connected to
# ====================================================================================================
# input_11 (InputLayer)            (None, 3, 96, 96)     0
# ____________________________________________________________________________________________________
# convolution2d_24 (Convolution2D) (None, 192, 48, 48)   14592       input_11[0][0]
# ____________________________________________________________________________________________________
# leakyrelu_47 (LeakyReLU)         (None, 192, 48, 48)   0           convolution2d_24[0][0]
# ____________________________________________________________________________________________________
# dropout_16 (Dropout)             (None, 192, 48, 48)   0           leakyrelu_47[0][0]
# ____________________________________________________________________________________________________
# convolution2d_25 (Convolution2D) (None, 256, 24, 24)   1229056     dropout_16[0][0]
# ____________________________________________________________________________________________________
# leakyrelu_48 (LeakyReLU)         (None, 256, 24, 24)   0           convolution2d_25[0][0]
# ____________________________________________________________________________________________________
# dropout_17 (Dropout)             (None, 256, 24, 24)   0           leakyrelu_48[0][0]
# ____________________________________________________________________________________________________
# convolution2d_26 (Convolution2D) (None, 256, 12, 12)   1638656     dropout_17[0][0]
# ____________________________________________________________________________________________________
# leakyrelu_49 (LeakyReLU)         (None, 256, 12, 12)   0           convolution2d_26[0][0]
# ____________________________________________________________________________________________________
# dropout_18 (Dropout)             (None, 256, 12, 12)   0           leakyrelu_49[0][0]
# ____________________________________________________________________________________________________
# convolution2d_27 (Convolution2D) (None, 384, 6, 6)     885120      dropout_18[0][0]
# ____________________________________________________________________________________________________
# leakyrelu_50 (LeakyReLU)         (None, 384, 6, 6)     0           convolution2d_27[0][0]
# ____________________________________________________________________________________________________
# dropout_19 (Dropout)             (None, 384, 6, 6)     0           leakyrelu_50[0][0]
# ____________________________________________________________________________________________________
# convolution2d_28 (Convolution2D) (None, 192, 6, 6)     73920       dropout_19[0][0]
# ____________________________________________________________________________________________________
# leakyrelu_51 (LeakyReLU)         (None, 192, 6, 6)     0           convolution2d_28[0][0]
# ____________________________________________________________________________________________________
# dropout_20 (Dropout)             (None, 192, 6, 6)     0           leakyrelu_51[0][0]
# ____________________________________________________________________________________________________
# flatten_4 (Flatten)              (None, 6912)          0           dropout_20[0][0]
# ____________________________________________________________________________________________________
# dense_11 (Dense)                 (None, 128)           884864      flatten_4[0][0]
# ____________________________________________________________________________________________________
# leakyrelu_52 (LeakyReLU)         (None, 128)           0           dense_11[0][0]
# ____________________________________________________________________________________________________
# dense_12 (Dense)                 (None, 2)             258         leakyrelu_52[0][0]
# ====================================================================================================
# Total params: 4,726,466
# Trainable params: 4,726,466
# Non-trainable params: 0
# ____________________________________________________________________________________________________
# ____________________________________________________________________________________________________
# Layer (type)                     Output Shape          Param #     Connected to
# ====================================================================================================
# input_12 (InputLayer)            (None, 100)           0
# ____________________________________________________________________________________________________
# model_10 (Model)                 (None, 3, 96, 96)     12153035    input_12[0][0]
# ____________________________________________________________________________________________________
# model_11 (Model)                 (None, 2)             4726466     model_10[1][0]
# ====================================================================================================
# Total params: 16,879,501
# Trainable params: 12,134,039
# Non-trainable params: 4,745,462
# ____________________________________________________________________________________________________

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns
from IPython import display

import pandas as pd
#pandas used to efficiently calculate rolling_mean

def plot_loss(
    losses, 
    names = (
        'discriminator accuracy real',
        'discriminator accuracy fake',
        #'discriminator logloss real',
        #'discriminator logloss fake',
        'generator accuracy',
        #'generator logloss',
    ),
    average_window = 100,
    display_loss_length = None
):
    display.clear_output(wait = True)
    display.display(plt.gcf())
    plt.figure(figsize=(12, 8))
    for name in names :
        if display_loss_length is None:
            arr = losses[name]
        else:
            arr = losses[:display_loss_length]
        plt.plot(
            pd.rolling_mean(pd.Series(arr), window = average_window).values, 
            label = name
        )
    
    plt.legend()
    plt.show()
    
def plot_grid(images, dimensions = (5, 5), figsize=(10, 10)) :
    plt.figure(figsize=figsize)
    for i in range(images.shape[0]):
        plt.subplot(dimensions[0], dimensions[1], i + 1)
        
        # (-1, 1) color range to (0, 1)
        image = (images[i, :, :, :] + 1.0) * 0.5
        
        plt.imshow(image)
        plt.axis('off')
        
    plt.tight_layout()
    plt.show()

plot_dimensions = (5, 5)
plot_image_count = np.prod(plot_dimensions)
fixed_noise = noise_generator(plot_image_count)

def plot_generator(n_images = plot_image_count, dimensions = plot_dimensions, figsize = (10, 10), fixed_set = True):
    if fixed_set :
        noise = fixed_noise
    else :
        noise = noise_generator(n_ex)
        
    generated_images = generator.predict(noise)
    
    # Convert to (height, width, RGB)
    generated_images = np.swapaxes(generated_images, 1, 2)
    generated_images = np.swapaxes(generated_images, 2, 3)
    
    plot_grid(generated_images, plot_dimensions, figsize)

# %%
plot_dimensions = (5, 5)
plot_image_count = np.prod(plot_dimensions)

def plot_real(X, images_count = plot_image_count, dimensions = plot_dimensions, figsize=(10,10)):
    images_ids = np.random.randint(0, X.shape[0], images_count)
    images = X[images_ids, :, :, :][:, :, :, :]
    
    
    images = np.swapaxes(images, 1, 2)
    images = np.swapaxes(images, 2, 3)
    
    plot_grid(images, dimensions = dimensions)
    
plot_real(X)

# %%
def swap_dimensions(images) :
    images = np.swapaxes(images, 1, 2)
    images = np.swapaxes(images, 2, 3)
    return images

def shake(v, rate = 0.1) :
    return v * np.random.uniform(1.0 - rate, 1.0 + rate, size=100)


def image_shaking(generator, images_count = 9, shakes_count = 9, noise = None) :
    if noise is None :
        noise = noise_generator(images_count)
    
    input_vectors = []
    for i in range(images_count) :        
        for j in range(shakes_count) :
            original = np.array(noise[i])
            if i > 0 :
                shaked = shake(original, 0.3)
            else :
                shaked = original
                
            input_vectors.append(shaked)
    
    input_vectors = np.stack(input_vectors)
    generated_images = generator.predict(input_vectors, batch_size = images_count * shakes_count)
    generated_images = np.swapaxes(generated_images, 1, 2)
    generated_images = np.swapaxes(generated_images, 2, 3)
    generated_images = (generated_images + 1.0) * 0.5
        
    return generated_images

# %%
import cv2

def convert_to_tiles(images, target_tiling = (9, 9), image_size = (96, 96)) :
    width = target_tiling[1] * (image_size[1] + 1) - 1
    height = target_tiling[0] * (image_size[0] + 1) - 1
    
    result = np.ones((height, width, 3), dtype = np.uint8) * 255
    for index, image in zip(
        range(target_tiling[0] * target_tiling[1]),
        (images * 255).astype(np.uint8)
    ) :
        x_index = index % target_tiling[1]
        y_index = index // target_tiling[1]
        
        left = x_index * (image_size[0] + 1)
        top = y_index * (image_size[1] + 1)
        
        result[top:top + image_size[1], left:left + image_size[0]] = image 
        
    return result

def save_tiled(images, filename, grid_in_row, grid_in_column, image_size = (48, 48)) :
    tiled = convert_to_tiles(
        images, 
        target_tiling = (grid_in_row, grid_in_column), 
        image_size = image_size
    )
    
    # Convert RGB to BGR before saving in opencv

    return cv2.imwrite(filename, tiled[:, :, [2, 1, 0]])

# %%
losses = dict([
    (name, []) for name in (
        'discriminator accuracy real',
        'discriminator accuracy fake',
        'discriminator logloss real',
        'discriminator logloss fake',
        'generator accuracy',
        'generator logloss',
    )
])
losses
# Out:
# {'discriminator accuracy fake': [],
#  'discriminator accuracy real': [],
#  'discriminator logloss fake': [],
#  'discriminator logloss real': [],
#  'generator accuracy': [],
#  'generator logloss': []}

# %%
train_gan(discriminator, gan, generator, losses, epoch_count = 50000, plot_frequency = 200, batch_size=32, display_loss_length = None)
# Out:
#  64%|██████▍   | 32164/50000 [13:02:31<7:08:56,  1.44s/it]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-32-97c7de4ba8e4> in <module>()
# ----> 1 train_gan(discriminator, gan, generator, losses, epoch_count = 50000, plot_frequency = 200, batch_size=32, display_loss_length = None)
#
# <ipython-input-30-bd2ab7f2167e> in train_gan(discriminator, gan, generator, losses, epoch_count, plot_frequency, render_frequency, batch_size, history_length, train_dis, train_gen, display_loss_length)
#      90
#      91         if train_dis:
# ---> 92             train_discriminator(discriminator, history, X, batch_size, losses)
#      93         if train_gen:
#      94             train_generator(gan, generator, batch_size, losses)
#
# <ipython-input-30-bd2ab7f2167e> in train_discriminator(discriminator, history, X, batch_size, losses)
#      31     y[:, 0] = -y[:, 1] + 1.0
#      32
# ---> 33     loss_real, accuracy_real  = discriminator.train_on_batch(X_real, y)
#      34     for name, loss in [
#      35         ('discriminator accuracy real', accuracy_real),
#
# /home/yiyuezhuo/anaconda3/lib/python3.6/site-packages/keras/engine/training.py in train_on_batch(self, x, y, sample_weight, class_weight)
#    1314             ins = x + y + sample_weights
#    1315         self._make_train_function()
# -> 1316         outputs = self.train_function(ins)
#    1317         if len(outputs) == 1:
#    1318             return outputs[0]
#
# /home/yiyuezhuo/anaconda3/lib/python3.6/site-packages/keras/backend/theano_backend.py in __call__(self, inputs)
#     957     def __call__(self, inputs):
#     958         assert isinstance(inputs, (list, tuple))
# --> 959         return self.function(*inputs)
#     960
#     961
#
# /home/yiyuezhuo/anaconda3/lib/python3.6/site-packages/theano/compile/function_module.py in __call__(self, *args, **kwargs)
#     857         t0_fn = time.time()
#     858         try:
# --> 859             outputs = self.fn()
#     860         except Exception:
#     861             if hasattr(self.fn, 'position_of_error'):
#
# /home/yiyuezhuo/anaconda3/lib/python3.6/site-packages/theano/ifelse.py in thunk()
#     235         outputs = node.outputs
#     236
# --> 237         def thunk():
#     238             if not compute_map[cond][0]:
#     239                 return [0]
#
# KeyboardInterrupt:

# %%
discriminator.optimizer.lr.get_value()
# Out:
# array(0.5, dtype=float32)

# %%
discriminator.optimizer.lr.set_value((discriminator.optimizer.lr.get_value()/10).astype('float32'))

# %%
discriminator.optimizer.lr.get_value()
# Out:
# array(0.05000000074505806, dtype=float32)

# %%
generator2, discriminator2, gan2, generator_optimizer2, discriminator_optimizer2 = build_models()
# Out:
# ____________________________________________________________________________________________________
# Layer (type)                     Output Shape          Param #     Connected to
# ====================================================================================================
# input_7 (InputLayer)             (None, 100)           0
# ____________________________________________________________________________________________________
# dense_7 (Dense)                  (None, 9216)          930816      input_7[0][0]
# ____________________________________________________________________________________________________
# batchnormalization_15 (BatchNorm (None, 9216)          36864       dense_7[0][0]
# ____________________________________________________________________________________________________
# leakyrelu_27 (LeakyReLU)         (None, 9216)          0           batchnormalization_15[0][0]
# ____________________________________________________________________________________________________
# reshape_3 (Reshape)              (None, 1024, 3, 3)    0           leakyrelu_27[0][0]
# ____________________________________________________________________________________________________
# deconvolution2d_11 (Deconvolutio (None, 512, 8, 8)     8389120     reshape_3[0][0]
# ____________________________________________________________________________________________________
# cropping2d_11 (Cropping2D)       (None, 512, 6, 6)     0           deconvolution2d_11[0][0]
# ____________________________________________________________________________________________________
# batchnormalization_16 (BatchNorm (None, 512, 6, 6)     24          cropping2d_11[0][0]
# ____________________________________________________________________________________________________
# leakyrelu_28 (LeakyReLU)         (None, 512, 6, 6)     0           batchnormalization_16[0][0]
# ____________________________________________________________________________________________________
# deconvolution2d_12 (Deconvolutio (None, 256, 14, 14)   2097408     leakyrelu_28[0][0]
# ____________________________________________________________________________________________________
# cropping2d_12 (Cropping2D)       (None, 256, 12, 12)   0           deconvolution2d_12[0][0]
# ____________________________________________________________________________________________________
# batchnormalization_17 (BatchNorm (None, 256, 12, 12)   48          cropping2d_12[0][0]
# ____________________________________________________________________________________________________
# leakyrelu_29 (LeakyReLU)         (None, 256, 12, 12)   0           batchnormalization_17[0][0]
# ____________________________________________________________________________________________________
# deconvolution2d_13 (Deconvolutio (None, 128, 26, 26)   524416      leakyrelu_29[0][0]
# ____________________________________________________________________________________________________
# cropping2d_13 (Cropping2D)       (None, 128, 24, 24)   0           deconvolution2d_13[0][0]
# ____________________________________________________________________________________________________
# batchnormalization_18 (BatchNorm (None, 128, 24, 24)   96          cropping2d_13[0][0]
# ____________________________________________________________________________________________________
# leakyrelu_30 (LeakyReLU)         (None, 128, 24, 24)   0           batchnormalization_18[0][0]
# ____________________________________________________________________________________________________
# deconvolution2d_14 (Deconvolutio (None, 64, 50, 50)    131136      leakyrelu_30[0][0]
# ____________________________________________________________________________________________________
# cropping2d_14 (Cropping2D)       (None, 64, 48, 48)    0           deconvolution2d_14[0][0]
# ____________________________________________________________________________________________________
# batchnormalization_19 (BatchNorm (None, 64, 48, 48)    192         cropping2d_14[0][0]
# ____________________________________________________________________________________________________
# leakyrelu_31 (LeakyReLU)         (None, 64, 48, 48)    0           batchnormalization_19[0][0]
# ____________________________________________________________________________________________________
# deconvolution2d_15 (Deconvolutio (None, 32, 98, 98)    32800       leakyrelu_31[0][0]
# ____________________________________________________________________________________________________
# cropping2d_15 (Cropping2D)       (None, 32, 96, 96)    0           deconvolution2d_15[0][0]
# ____________________________________________________________________________________________________
# batchnormalization_20 (BatchNorm (None, 32, 96, 96)    384         cropping2d_15[0][0]
# ____________________________________________________________________________________________________
# leakyrelu_32 (LeakyReLU)         (None, 32, 96, 96)    0           batchnormalization_20[0][0]
# ____________________________________________________________________________________________________
# convolution2d_15 (Convolution2D) (None, 32, 96, 96)    9248        leakyrelu_32[0][0]
# ____________________________________________________________________________________________________
# batchnormalization_21 (BatchNorm (None, 32, 96, 96)    384         convolution2d_15[0][0]
# ____________________________________________________________________________________________________
# leakyrelu_33 (LeakyReLU)         (None, 32, 96, 96)    0           batchnormalization_21[0][0]
# ____________________________________________________________________________________________________
# convolution2d_16 (Convolution2D) (None, 3, 96, 96)     99          leakyrelu_33[0][0]
# ____________________________________________________________________________________________________
# activation_3 (Activation)        (None, 3, 96, 96)     0           convolution2d_16[0][0]
# ====================================================================================================
# Total params: 12,153,035
# Trainable params: 12,134,039
# Non-trainable params: 18,996
# ____________________________________________________________________________________________________
# ____________________________________________________________________________________________________
# Layer (type)                     Output Shape          Param #     Connected to
# ====================================================================================================
# input_8 (InputLayer)             (None, 3, 96, 96)     0
# ____________________________________________________________________________________________________
# convolution2d_17 (Convolution2D) (None, 192, 48, 48)   14592       input_8[0][0]
# ____________________________________________________________________________________________________
# leakyrelu_34 (LeakyReLU)         (None, 192, 48, 48)   0           convolution2d_17[0][0]
# ____________________________________________________________________________________________________
# dropout_11 (Dropout)             (None, 192, 48, 48)   0           leakyrelu_34[0][0]
# ____________________________________________________________________________________________________
# convolution2d_18 (Convolution2D) (None, 256, 24, 24)   1229056     dropout_11[0][0]
# ____________________________________________________________________________________________________
# leakyrelu_35 (LeakyReLU)         (None, 256, 24, 24)   0           convolution2d_18[0][0]
# ____________________________________________________________________________________________________
# dropout_12 (Dropout)             (None, 256, 24, 24)   0           leakyrelu_35[0][0]
# ____________________________________________________________________________________________________
# convolution2d_19 (Convolution2D) (None, 256, 12, 12)   1638656     dropout_12[0][0]
# ____________________________________________________________________________________________________
# leakyrelu_36 (LeakyReLU)         (None, 256, 12, 12)   0           convolution2d_19[0][0]
# ____________________________________________________________________________________________________
# dropout_13 (Dropout)             (None, 256, 12, 12)   0           leakyrelu_36[0][0]
# ____________________________________________________________________________________________________
# convolution2d_20 (Convolution2D) (None, 384, 6, 6)     885120      dropout_13[0][0]
# ____________________________________________________________________________________________________
# leakyrelu_37 (LeakyReLU)         (None, 384, 6, 6)     0           convolution2d_20[0][0]
# ____________________________________________________________________________________________________
# dropout_14 (Dropout)             (None, 384, 6, 6)     0           leakyrelu_37[0][0]
# ____________________________________________________________________________________________________
# convolution2d_21 (Convolution2D) (None, 192, 6, 6)     73920       dropout_14[0][0]
# ____________________________________________________________________________________________________
# leakyrelu_38 (LeakyReLU)         (None, 192, 6, 6)     0           convolution2d_21[0][0]
# ____________________________________________________________________________________________________
# dropout_15 (Dropout)             (None, 192, 6, 6)     0           leakyrelu_38[0][0]
# ____________________________________________________________________________________________________
# flatten_3 (Flatten)              (None, 6912)          0           dropout_15[0][0]
# ____________________________________________________________________________________________________
# dense_8 (Dense)                  (None, 128)           884864      flatten_3[0][0]
# ____________________________________________________________________________________________________
# leakyrelu_39 (LeakyReLU)         (None, 128)           0           dense_8[0][0]
# ____________________________________________________________________________________________________
# dense_9 (Dense)                  (None, 2)             258         leakyrelu_39[0][0]
# ====================================================================================================
# Total params: 4,726,466
# Trainable params: 4,726,466
# Non-trainable params: 0
# ____________________________________________________________________________________________________
# ____________________________________________________________________________________________________
# Layer (type)                     Output Shape          Param #     Connected to
# ====================================================================================================
# input_9 (InputLayer)             (None, 100)           0
# ____________________________________________________________________________________________________
# model_7 (Model)                  (None, 3, 96, 96)     12153035    input_9[0][0]
# ____________________________________________________________________________________________________
# model_8 (Model)                  (None, 2)             4726466     model_7[1][0]
# ====================================================================================================
# Total params: 16,879,501
# Trainable params: 12,134,039
# Non-trainable params: 4,745,462
# ____________________________________________________________________________________________________

# %%
discriminator.set_weights(discriminator2.get_weights())
